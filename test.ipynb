# %%
import torch.nn as nn
from cnnFactory import CNNFactory
# %load_ext autoreload
# %autoreload 2

# %%
testNet = nn.Sequential(
    nn.Conv2d(1, 6, 5),
    nn.ReLU(),
    nn.MaxPool2d(2, 2),
    nn.Conv2d(6, 16, 5),
    nn.ReLU(),
    nn.MaxPool2d(2, 2),
)

classify_layer = nn.Sequential(
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Linear(64, 10),
)

input_shape = [100,100]
factory = CNNFactory(input_shape, testNet, classify_layer)
print(factory.validate())
output = factory.compute_cnn_output_shape()
print(output)
print(factory.compute_ffn_input_shape())
ffn_layer = factory.create_flatten_layer()


final_net = factory.create()
final_net.state_dict()
# Out:
# True
# [22.0, 22.0]
# 7744.0
# OrderedDict([('0.0.weight',
#               tensor([[[[-0.0702,  0.1728,  0.0257,  0.1964, -0.0708],
#                         [-0.0588, -0.1278,  0.0555,  0.1061, -0.0459],
#                         [-0.1346,  0.1405, -0.1637,  0.1261, -0.0993],
#                         [-0.1178,  0.1112,  0.1600,  0.0428,  0.0129],
#                         [ 0.1835, -0.0708, -0.1232, -0.0388,  0.1465]]],
#
#
#                       [[[-0.0135, -0.0817,  0.0306, -0.1248, -0.0211],
#                         [ 0.1317, -0.0696,  0.0791,  0.0873,  0.0635],
#                         [-0.0194,  0.1468, -0.1050, -0.0462, -0.0883],
#                         [-0.1325, -0.0224,  0.0073,  0.0760, -0.0950],
#                         [-0.0402, -0.1191,  0.1032,  0.1461, -0.1270]]],
#
#
#                       [[[ 0.1579,  0.0084, -0.1256,  0.0356, -0.0191],
#                         [-0.1423,  0.1314,  0.0553, -0.0877, -0.0584],
# ...
